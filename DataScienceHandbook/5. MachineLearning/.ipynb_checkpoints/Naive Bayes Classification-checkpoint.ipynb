# %% [markdown]
# # Naive Bayes Classification

# %% [markdown]
# #### Bayesian Classification
# - Naive Bayes Classification: "naive" in "naive Bayes" comes in: if we make very naive assumptions about the generative model for each label, we can find a rough approximation of the generative model for each class, and then proceed with the Bayesian classification.
# - Finding the probability of a label given some observed features :
#
#     $P(L~|~{\rm features}) = \frac{P({\rm features}~|~L)P(L)}{P({\rm features})}$
#
# - If we are trying to decide between two labels—let's call them $L_1$ and $L_2$—then one way to make this decision is to compute the ratio of the posterior probabilities for each label:
#
#     $\frac{P(L_1~|~{\rm features})}{P(L_2~|~{\rm features})} = \frac{P({\rm features}~|~L_1)}{P({\rm features}~|~L_2)}\frac{P(L_1)}{P(L_2)}$
#
# - If you are looking for estimates of uncertainty in your classification, Bayesian approaches like this can be a useful approach.
#
# - Gaussian naive bayes will only be as good as the model assumptions that lead to it. it dones not produce very good results at real cases. But, Gaussian naive bayes is still useful method.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Gaussian Naive Bayes
from sklearn.datasets import make_blobs
X, y = make_blobs(100,2,centers=2,random_state=2,cluster_std=1.5)
sns.set()
plt.scatter(X[:,0],X[:,1],c=y,cmap='RdBu')

# %% [markdown]
# **<font color='red'>One extremely fast way to create a simple model is to assume that the data is described by a Gaussian distribution with no covariance between dimensions. </font>**

# %%
from sklearn.naive_bayes import GaussianNB #1. Choose classification model
clf = GaussianNB() # instantate model
clf.fit(X,y)  # fit model
# Out:
# GaussianNB(priors=None)

# %%
# Generate some new data for prediction

X_new = [-6, -14] + [10, 20] *np.random.RandomState(0).rand(1000,2)
y_new = clf.predict(X_new)

# %%
X, y = make_blobs(100,2,centers=2,random_state=2,cluster_std=1.5)
plt.scatter(X[:,0],X[:,1],c=y,cmap='RdBu')
X, y = make_blobs(100,2,centers=2,random_state=2,cluster_std=1.5)
plt.scatter(X_new[:,0],X_new[:,1],c=y_new,cmap='RdBu',alpha=0.1)
